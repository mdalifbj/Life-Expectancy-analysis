# %%
import numpy as np
import sklearn
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Latitude 3470\Downloads\archive(6)\Life Expectancy Data.csv")

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
data.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
print('Total missing values in the data: ', data.isnull().sum().sum(), '\n\n')
print('Missing values per column \n\n',data.isnull().sum())
# Out:
# Total missing values in the data:  2563
#
#
# Missing values per column
#
#  Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data = data[data['Life expectancy'].isna()==False]

# %%
data = data[data['Life expectancy'].isna()==False]

#Filtered out missing values from "Life expectancy" column.

data = data[data['Population'].isna()==False]

#Filtered out missing values from "Population" column.

data = data[data['Alcohol'].isna()==False]

data['GDP'] = data['GDP'].fillna(data['GDP'].median())

# %%
mean_col_list = ['Hepatitis B', 'BMI', 'Polio', 'Total expenditure', 'Diphtheria','thinness 5-9 years', 
                 'thinness  1-19 years', 'Income composition of resources', 'Schooling']

# %%
def replace_mean(series):
    series = series.fillna(series.mean(),inplace=True)
    return series
for series in mean_col_list:
    replace_mean(data[series])

data.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
#ANALYZE
data['Country'].describe()
# Out:
# count            2129
# unique            142
# top       Afghanistan
# freq               16
# Name: Country, dtype: object

# %%
country_count = data.value_counts('Country')
country_count
# Out:
# Country
# Afghanistan    16
# Norway         16
# Albania        16
# Poland         15
# Philippines    15
#                ..
# Greece         15
# Guatemala      15
# Zimbabwe       15
# Montenegro     14
# Eritrea        12
# Name: count, Length: 142, dtype: int64

# %%
year_count =data.value_counts('Year')
year_count
# Out:
# Year
# 2000    142
# 2001    142
# 2002    142
# 2003    142
# 2004    142
# 2006    142
# 2007    142
# 2008    142
# 2009    142
# 2010    142
# 2011    142
# 2005    141
# 2012    141
# 2013    141
# 2014    141
# 2015      3
# Name: count, dtype: int64

# %%
data['Life expectancy'].describe()
# Out:
# count    2129.000000
# mean       68.631517
# std         9.852486
# min        36.300000
# 25%        62.200000
# 50%        71.400000
# 75%        75.400000
# max        89.000000
# Name: Life expectancy, dtype: float64

# %%
plt.figure(figsize=(6,2))
sb.boxplot(x= data['Life expectancy'])
plt.title('Distribution of Life Expectancy')
plt.show()

# %%
sb.histplot(data['Life expectancy'],binrange=(35,90),bins=12)
plt.xticks(list(range(35,95,5)))
plt.xlabel('Life expectancy')

# %%
plt.figure(figsize=(6,2))
sb.boxplot(x= data['Adult Mortality'])
plt.title('Distribution of Adult Mortality')
plt.show()

# %%
plt.figure(figsize=(6,2))
sb.boxplot(x= data['Total expenditure'])
plt.title('Distribution of Total expenditure')
plt.show()

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
remove_list = ['Country', 'Year', 'Status']

# %%
data.update = data.drop(remove_list,axis=1)

# %%
data.update.corr()
# Out:
#                                  Life expectancy  Adult Mortality  \
# Life expectancy                         1.000000        -0.672555
# Adult Mortality                        -0.672555         1.000000
# infant deaths                          -0.171809         0.049739
# Alcohol                                 0.429497        -0.215930
# percentage expenditure                  0.428769        -0.262226
# Hepatitis B                             0.158069        -0.086891
# Measles                                -0.140336        -0.001149
# BMI                                     0.593071        -0.378940
# under-five deaths                      -0.197561         0.064348
# Polio                                   0.434325        -0.225870
# Total expenditure                       0.232358        -0.124106
# Diphtheria                              0.456059        -0.226444
# HIV/AIDS                               -0.569305         0.536646
# ...

# %%
plt.figure(figsize=(10,6))
sb.heatmap(data.update.corr())
plt.title('Correlation Graph')
# Out:
# Text(0.5, 1.0, 'Correlation Graph')

# %%
variable_list = ['Schooling', 'Income composition of resources', 'GDP', 'Diphtheria', 
                'Polio', 'BMI', 'percentage expenditure', 'Alcohol', 'Life expectancy']
data_last = data.update[variable_list]
data_last.head()
# Out:
#    Schooling  Income composition of resources         GDP  Diphtheria  Polio  \
# 0       10.1                            0.479  584.259210        65.0    6.0
# 1       10.0                            0.476  612.696514        62.0   58.0
# 2        9.9                            0.470  631.744976        64.0   62.0
# 3        9.8                            0.463  669.959000        67.0   67.0
# 4        9.5                            0.454   63.537231        68.0   68.0
#
#     BMI  percentage expenditure  Alcohol  Life expectancy
# 0  19.1               71.279624     0.01             65.0
# 1  18.6               73.523582     0.01             59.9
# 2  18.1               73.219243     0.01             59.9
# 3  17.6               78.184215     0.01             59.5
# 4  17.2                7.097109     0.01             59.2

# %%
sb.pairplot(data_last);

# %%
sb.heatmap(data_last.corr())
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
data_last = data_last.join(data[remove_list])
data_last.head()
# Out:
#    Schooling  Income composition of resources         GDP  Diphtheria  Polio  \
# 0       10.1                            0.479  584.259210        65.0    6.0
# 1       10.0                            0.476  612.696514        62.0   58.0
# 2        9.9                            0.470  631.744976        64.0   62.0
# 3        9.8                            0.463  669.959000        67.0   67.0
# 4        9.5                            0.454   63.537231        68.0   68.0
#
#     BMI  percentage expenditure  Alcohol  Life expectancy      Country  Year  \
# 0  19.1               71.279624     0.01             65.0  Afghanistan  2015
# 1  18.6               73.523582     0.01             59.9  Afghanistan  2014
# 2  18.1               73.219243     0.01             59.9  Afghanistan  2013
# 3  17.6               78.184215     0.01             59.5  Afghanistan  2012
# 4  17.2                7.097109     0.01             59.2  Afghanistan  2011
#
#        Status
# 0  Developing
# ...

# %%
X = data_last.drop('Life expectancy', axis=1)
y = data_last['Life expectancy']

# %%
X['Year'] = X['Year'].astype('str')

X = pd.get_dummies(X, drop_first=True)
X.head()
# Out:
#    Schooling  Income composition of resources         GDP  Diphtheria  Polio  \
# 0       10.1                            0.479  584.259210        65.0    6.0
# 1       10.0                            0.476  612.696514        62.0   58.0
# 2        9.9                            0.470  631.744976        64.0   62.0
# 3        9.8                            0.463  669.959000        67.0   67.0
# 4        9.5                            0.454   63.537231        68.0   68.0
#
#     BMI  percentage expenditure  Alcohol  Country_Albania  Country_Algeria  \
# 0  19.1               71.279624     0.01            False            False
# 1  18.6               73.523582     0.01            False            False
# 2  18.1               73.219243     0.01            False            False
# 3  17.6               78.184215     0.01            False            False
# 4  17.2                7.097109     0.01            False            False
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[-0.53071777 -0.66269761 -0.44209277 ... -0.26631852 26.62079388
#    0.47431132]
#  [-0.56059898 -0.67700116 -0.44001983 ...  3.75490223 -0.03756462
#    0.47431132]
#  [-0.59048019 -0.70560826 -0.43863129 ... -0.26631852 -0.03756462
#    0.47431132]
#  ...
#  [-0.56059898 -0.91062583 -0.48050205 ... -0.26631852 -0.03756462
#    0.47431132]
#  [-0.62036139 -0.91062583 -0.44469308 ... -0.26631852 -0.03756462
#    0.47431132]
#  [-0.62036139 -0.87725088 -0.44478263 ... -0.26631852 -0.03756462
#    0.47431132]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)
ml = LinearRegression()
ml.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficient of determination: ', ml.score(X_train, y_train))
# Out:
# Coefficient of determination:  0.9606421421996297

# %%
y_pred = ml.predict(X_train)

# %%
print('R^2: ', r2_score(y_train, y_pred))
print('MAE: ',mean_absolute_error(y_train, y_pred))
print('MSE: ', mean_squared_error(y_train, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_train, y_pred)))
# Out:
# R^2:  0.9606421421996297
# MAE:  1.2512806261587714
# MSE:  3.844029188000169
# RMSE:  1.9606195928838845

# %%
print('Coefficient of determination: ', ml.score(X_test, y_test))
# Out:
# Coefficient of determination:  0.9388778562419247

# %%
y_pred_test = ml.predict(X_test)

# %%
print('R^2: ', r2_score(y_test, y_pred_test))
print('MAE: ',mean_absolute_error(y_test, y_pred_test))
print('MSE: ', mean_squared_error(y_test, y_pred_test))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred_test)))
# Out:
# R^2:  0.9388778562419247
# MAE:  1.5096861554358372
# MSE:  5.768364453476181
# RMSE:  2.401741962300734

# %%
results = pd.DataFrame({'actual': y_test, 
              'predicted': y_pred_test.ravel(), 
              'residual': y_test - y_pred_test})
results.head(22)
# Out:
#       actual  predicted  residual
# 395     72.2  71.268584  0.931416
# 2692    72.0  72.679068 -0.679068
# 2299    54.0  48.668936  5.331064
# 1698    74.8  73.193716  1.606284
# 2712    63.8  60.168082  3.631918
# 411     52.4  54.037222 -1.637222
# 2365    68.5  69.927359 -1.427359
# 1884    56.0  56.187857 -0.187857
# 89      75.2  75.089712  0.110288
# 404     58.1  57.515250  0.584750
# 2307    43.3  44.631338 -1.331338
# 2705    64.1  64.326773 -0.226773
# 684     78.6  77.180693  1.419307
# 2620    58.9  58.529654  0.370346
# 1236    69.5  73.444937 -3.944937
# 590     71.5  70.737173  0.762827
# 2655    71.0  71.767935 -0.767935
# 2444    74.5  74.730093 -0.230093
# 271     68.3  67.167471  1.132529
# 131     88.0  82.814971  5.185029
# 1738    75.0  75.596793 -0.596793
# 2907    61.1  56.521963  4.578037

# %%
sb.scatterplot(x=results['actual'], 
                y=results['predicted'])
plt.title('Actual vs Predicted values')
plt.show()

# %%
sb.histplot(results['residual'], bins=np.arange(-10,10,0.5))
plt.title('Histogram of residuals')
plt.show()

# %%
results['residual'].mean()
# Out:
# 0.1357893813453611

# %%
sb.scatterplot(x=results['predicted'], y=results['residual'])
plt.axhline(0, c='red')
plt.title('Scatterplot of residuals over predicted')
plt.show()

# %%
coefficients = pd.DataFrame(ml.coef_, index=X.columns).T
coefficients
# Out:
#    Schooling  Income composition of resources      GDP  Diphtheria     Polio  \
# 0   0.558841                          0.01032 -0.21496    0.171561  0.033963
#
#         BMI  percentage expenditure   Alcohol  Country_Albania  \
# 0 -0.085517                0.142611 -0.707468         1.465751
#
#    Country_Algeria  ...  Year_2007  Year_2008  Year_2009  Year_2010  \
# 0         1.228048  ...   0.592415    0.67334   0.792374   0.812119
#
#    Year_2011  Year_2012  Year_2013  Year_2014  Year_2015  Status_Developing
# 0   0.980362   0.968964   1.068542   1.092163    0.20163      -1.370771e+12
#
# [1 rows x 165 columns]
